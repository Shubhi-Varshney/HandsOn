# %%
import pandas as pd

df = pd.read_csv('D:\\Shubhi\\DataScience\\Pokemon\\pokemon_data.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.shape
# Out:
# (800, 12)

# %%
name = 'Charizard'
print(f" Pokemon Name Filtering: {name.upper()}")
df[df['Name'] == name]
# Out:
#  Pokemon Name Filtering: CHARIZARD
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 6  6  Charizard   Fire  Flying  78      84       78      109       85    100
#
#    Generation  Legendary
# 6           1      False

# %%
type = 'Dragon'
sort1 = 'Name'
sort2 = ['Attack', 'Defense']
print(f"All pokemons filtered by Type 1: {type.upper()} and sorted by : {sort2}")
print(f" Total no.{df[df['Type 1'] == type].shape[0]}")
#df[df['Type 1'] == type].sort_values(sort1)
df[df['Type 1'] == type].sort_values(sort2,ascending=[0,0])
# Out:
# All pokemons filtered by Type 1: DRAGON and sorted by : ['Attack', 'Defense']
#  Total no.32
#        #                     Name  Type 1    Type 2   HP  Attack  Defense  \
# 426  384    RayquazaMega Rayquaza  Dragon    Flying  105     180      100
# 494  445    GarchompMega Garchomp  Dragon    Ground  108     170      115
# 711  646       KyuremBlack Kyurem  Dragon       Ice  125     170      100
# 707  644                   Zekrom  Dragon  Electric  100     150      120
# 425  384                 Rayquaza  Dragon    Flying  105     150       90
# 673  612                  Haxorus  Dragon       NaN   76     147       90
# 409  373  SalamenceMega Salamence  Dragon    Flying   95     145      130
# 408  373                Salamence  Dragon    Flying   95     135       80
# 161  149                Dragonite  Dragon    Flying   91     134       95
# 420  381        LatiosMega Latios  Dragon   Psychic   80     130      100
# ...

# %%
print("All Column Names")
df.columns
# Out:
# All Column Names
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.loc[df['Legendary']].sort_values(['Attack', 'Defense'],ascending=[0,0])
df.loc[df['Legendary']].shape
df.loc[df['Type 1'] == 'Fire'].shape
# Out:
# (52, 12)

# %%
print(f"Total no. of rows: {df.shape[0]}" )
print(f"Total no. of Legendary Pokemons: { df.loc[df['Legendary']].shape[0]}")
print(f"Total no. of non-legendary Pokemons: {df.loc[~df['Legendary']].shape[0]}" )
# Out:
# Total no. of rows: 800
# Total no. of Legendary Pokemons: 65
# Total no. of non-legendary Pokemons: 735
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 270  250      Ho-oh   Fire  Flying  106     130       90      110      154
# 263  244      Entei   Fire     NaN  115     115       85       90       75
# 799  721  Volcanion   Fire   Water   80     110      120      130       90
# 158  146    Moltres   Fire  Flying   90     100       90      125       85
# 542  485    Heatran   Fire   Steel   91      90      106      130      106
#
#      Speed  Generation  Legendary
# 270     90           2       True
# 263    100           2       True
# 799     70           6       True
# 158     90           1       True
# 542     77           4       True

# %%
type1 = input("Enter the Type 1 Pokemon: ") 
sort = ['Attack', 'Defense']
print(f"List of all Legendary {type1} Pokemons sort by {sort}")
df.loc[(df['Type 1'] == type1)  & (df['Legendary'])].sort_values(sort,ascending=[0,0])
# Out:
# Enter the Type 1 Pokemon: Ice
# List of all Legendary Ice Pokemons sort by ['Attack', 'Defense']
#        #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 156  144  Articuno    Ice  Flying  90      85      100       95      125
# 415  378    Regice    Ice     NaN  80      50      100      100      200
#
#      Speed  Generation  Legendary
# 156     85           1       True
# 415     50           3       True

# %%
# type1 = input("Enter the Type 1 Pokemon: ") 
# gen = input("Enter the Generation: ") 

# print(f"List of all Type 1 {type1} and Generation {gen} Pokemons")

# df[(df['Generation'] == gen) & (df['Type 1'] == type1)]
type(df[df['Type 1'] == 'Dragon'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [121], in <cell line: 7>()
#       1 # type1 = input("Enter the Type 1 Pokemon: ")
#       2 # gen = input("Enter the Generation: ")
#       3
#       4 # print(f"List of all Type 1 {type1} and Generation {gen} Pokemons")
#       5
#       6 # df[(df['Generation'] == gen) & (df['Type 1'] == type1)]
# ----> 7 type(df[df['Type 1'] == 'Dragon'])
#
# TypeError: 'str' object is not callable
