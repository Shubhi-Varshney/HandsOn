# %%
import pandas as pd
credits = pd.read_csv('D:\\Shubhi\\DataScience\\MoviesRecommendation\\MovieLens_Dataset\\credits.csv')
keywords = pd.read_csv('D:\\Shubhi\\DataScience\\MoviesRecommendation\\MovieLens_Dataset\\keywords.csv')
md = pd.read_csv('D:\\Shubhi\\DataScience\\MoviesRecommendation\\MovieLens_Dataset\\movies_metadata.csv')
# Out:
# C:\Users\Ridaan\AppData\Local\Temp\ipykernel_3648\1456730466.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   md = pd.read_csv('D:\\Shubhi\\DataScience\\MoviesRecommendation\\MovieLens_Dataset\\movies_metadata.csv')

# %%
md = md.drop([19730, 29503, 35587])

# %%
print(md.shape)
print(credits.shape)
# Out:
# (45463, 24)
# (45476, 3)

# %%
md['id'] = md[md['id'].notnull()]['id'].astype('int')

md[md['id'] == 97995].transpose()
# Out:
#                                                                    13946  \
# adult                                                              FALSE
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                    [{"id": 35, "name": "Comedy"}]
# homepage                                                             NaN
# id                                                                 97995
# imdb_id                                                        tt0127834
# original_language                                                     en
# original_title                                      Seven Years Bad Luck
# overview               After breaking a mirror in his home, superstit...
# popularity                                                      0.141558
# poster_path                             /4J6Ai4C5YRgfRUTlirrJ7QsmJKU.jpg
# ...

# %%
md[md.duplicated()]
# Out:
#        adult belongs_to_collection  budget  \
# 1465   FALSE                   NaN       0
# 9165   FALSE                   NaN       0
# 9327   FALSE                   NaN       0
# 13375  FALSE                   NaN       0
# 16764  FALSE                   NaN       0
# 21165  FALSE                   NaN       0
# 21854  FALSE                   NaN       0
# 22151  FALSE                   NaN       0
# 23044  FALSE                   NaN       0
# 24844  FALSE                   NaN       0
# 28860  FALSE                   NaN       0
# 29374  FALSE                   NaN       0
# 40040  FALSE                   NaN  980000
#
#                                                   genres  \
# 1465   [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 9165   [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 9327   [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 13375  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...
# 16764  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...
# ...

# %%
md['id'] = md[md['id'].notnull()]['id'].astype('int')
md = md[~md.duplicated()]
md.shape
# Out:
# (45450, 24)

# %%
print(md['id'].is_unique)
md.groupby('id').count().sort_values(by = 'adult', ascending=False).head(30)
# Out:
# False
#         adult  belongs_to_collection  budget  genres  homepage  imdb_id  \
# id
# 97995       2                      0       2       2         0        2
# 77221       2                      0       2       2         0        2
# 132641      2                      0       2       2         0        2
# 22649       2                      0       2       2         0        2
# 159849      2                      2       2       2         0        2
# 99080       2                      0       2       2         0        2
# 109962      2                      0       2       2         0        2
# 265189      2                      0       2       2         0        2
# 13209       2                      0       2       2         0        2
# 110428      2                      0       2       2         0        2
# 15028       2                      0       2       2         0        2
# 84198       2                      0       2       2         0        2
# ...

# %%
credits[credits['id'] == 141971]
# Out:
#                                                     cast  \
# 13261  [{'cast_id': 1, 'character': 'Pekka', 'credit_...
# 13375  [{'cast_id': 1, 'character': 'Pekka', 'credit_...
# 16764  [{'cast_id': 1, 'character': 'Pekka', 'credit_...
#
#                                                     crew      id
# 13261  [{'credit_id': '52fe4ac89251416c750edd47', 'de...  141971
# 13375  [{'credit_id': '52fe4ac89251416c750edd47', 'de...  141971
# 16764  [{'credit_id': '52fe4ac89251416c750edd47', 'de...  141971

# %%
smd = md.merge(credits, on = 'id')
smd.shape
# Out:
# (45538, 26)

# %%
smd.groupby('id').count().sort_values(by = 'adult', ascending=False).head(30)
# Out:
#         adult  belongs_to_collection  budget  genres  homepage  imdb_id  \
# id
# 141971      9                      0       9       9         0        9
# 152795      4                      0       4       4         0        4
# 12600       4                      4       4       4         4        4
# 97995       4                      0       4       4         0        4
# 5511        4                      0       4       4         0        4
# 42495       4                      0       4       4         0        4
# 11115       4                      0       4       4         4        4
# 25541       4                      0       4       4         0        4
# 99080       4                      0       4       4         0        4
# 13209       4                      0       4       4         0        4
# 18440       4                      0       4       4         4        4
# 84198       4                      0       4       4         0        4
# ...

# %%
smd[smd['id'] == 141971]
# Out:
#        adult belongs_to_collection budget  \
# 13308  FALSE                   NaN      0
# 13309  FALSE                   NaN      0
# 13310  FALSE                   NaN      0
# 13311  FALSE                   NaN      0
# 13312  FALSE                   NaN      0
# 13313  FALSE                   NaN      0
# 13314  FALSE                   NaN      0
# 13315  FALSE                   NaN      0
# 13316  FALSE                   NaN      0
#
#                                                   genres homepage      id  \
# 13308  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...      NaN  141971
# 13309  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...      NaN  141971
# 13310  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...      NaN  141971
# 13311  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...      NaN  141971
# 13312  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...      NaN  141971
# 13313  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...      NaN  141971
# ...

# %%
credits[credits['id'] == 141971]
# Out:
#                                                     cast  \
# 13261  [{'cast_id': 1, 'character': 'Pekka', 'credit_...
# 13375  [{'cast_id': 1, 'character': 'Pekka', 'credit_...
# 16764  [{'cast_id': 1, 'character': 'Pekka', 'credit_...
#
#                                                     crew      id
# 13261  [{'credit_id': '52fe4ac89251416c750edd47', 'de...  141971
# 13375  [{'credit_id': '52fe4ac89251416c750edd47', 'de...  141971
# 16764  [{'credit_id': '52fe4ac89251416c750edd47', 'de...  141971

# %%
md['id'].is_unique
# Out:
# False

# %%
credits['id'].is_unique
# Out:
# False

# %%
md = md[~md.duplicated()]

# %%
md['id'].is_unique
# Out:
# False

# %%
md.groupby('id').count().sort_values(by = 'adult', ascending=False).head(30)
# Out:
#         adult  belongs_to_collection  budget  genres  homepage  imdb_id  \
# id
# 97995       2                      0       2       2         0        2
# 77221       2                      0       2       2         0        2
# 132641      2                      0       2       2         0        2
# 22649       2                      0       2       2         0        2
# 159849      2                      2       2       2         0        2
# 99080       2                      0       2       2         0        2
# 109962      2                      0       2       2         0        2
# 265189      2                      0       2       2         0        2
# 13209       2                      0       2       2         0        2
# 110428      2                      0       2       2         0        2
# 15028       2                      0       2       2         0        2
# 84198       2                      0       2       2         0        2
# ...
